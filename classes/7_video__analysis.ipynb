# %% [markdown]
# 🎥 Recommended Video: [Video Object Detection Using Yolo](https://www.youtube.com/watch?v=Rwvd0PJF2jk)
#
#
#
# ## **7. Video Analysis**
#
# ### **7.1 What is Video Analysis?**
# Video analysis involves processing and interpreting video data to extract meaningful information. It builds on image-based computer vision techniques but extends them to handle temporal information across frames. Key tasks in video analysis include:
# - **Object Detection**: Identifying objects in each frame.
# - **Object Tracking**: Following objects across frames.
# - **Activity Recognition**: Understanding actions or events in a video.
#
# ---
#
# ### **7.2 Key Challenges in Video Analysis**
# - **Temporal Consistency**: Ensuring smooth transitions and accurate tracking across frames.
# - **Computational Complexity**: Processing video data requires significant computational resources.
# - **Variability**: Changes in lighting, perspective, and object appearance over time.
#
# ---
#
# ### **7.3 Code Example: Reading and Displaying a Video**
# Let’s start by reading and displaying a video using OpenCV.
#
# ```python
# import cv2
#
# # Open a video file
# video_path = 'example_video.mp4'
# cap = cv2.VideoCapture(video_path)
#
# # Check if the video was opened successfully
# if not cap.isOpened():
#     print("Error: Could not open video.")
# else:
#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             break
#
#         # Display the frame
#         cv2.imshow('Video', frame)
#
#         # Exit if 'q' is pressed
#         if cv2.waitKey(25) & 0xFF == ord('q'):
#             break
#
# # Release the video capture object and close windows
# cap.release()
# cv2.destroyAllWindows()
# ```
#
# #### **Explanation**:
# 1. `cv2.VideoCapture()` opens the video file.
# 2. `cap.read()` reads each frame of the video.
# 3. `cv2.imshow()` displays the frame in a window.
# 4. The loop continues until the video ends or the user presses 'q'.
#
# ---
#
# ### **7.4 Code Example: Object Detection in Videos**
# Let’s use a pre-trained YOLO model to detect objects in a video.
#
# ```python
# from ultralytics import YOLO
# import cv2
#
# # Load a pre-trained YOLO model
# model = YOLO('yolov8n.pt')
#
# # Open a video file
# video_path = 'example_video.mp4'
# cap = cv2.VideoCapture(video_path)
#
# # Process each frame
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # Perform object detection
#     results = model(frame)
#
#     # Visualize the results
#     annotated_frame = results[0].plot()
#
#     # Display the annotated frame
#     cv2.imshow('Object Detection', annotated_frame)
#
#     # Exit if 'q' is pressed
#     if cv2.waitKey(25) & 0xFF == ord('q'):
#         break
#
# # Release the video capture object and close windows
# cap.release()
# cv2.destroyAllWindows()
# ```
#
# #### **Explanation**:
# 1. The YOLO model detects objects in each frame.
# 2. The `results[0].plot()` method visualizes the detected objects with bounding boxes and labels.
# 3. The annotated frames are displayed in real-time.
#
# ---
#
# ### **7.5 Code Example: Object Tracking in Videos**
# Object tracking involves following objects across frames. Let’s use OpenCV’s `Tracker` API to track an object in a video.
#
# ```python
# import cv2
#
# # Open a video file
# video_path = 'example_video.mp4'
# cap = cv2.VideoCapture(video_path)
#
# # Initialize the tracker
# tracker = cv2.TrackerKCF_create()
#
# # Read the first frame
# ret, frame = cap.read()
# if not ret:
#     print("Error: Could not read video.")
#
# # Select a bounding box to track
# bbox = cv2.selectROI('Tracking', frame, False)
# tracker.init(frame, bbox)
#
# # Track the object in subsequent frames
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # Update the tracker
#     success, bbox = tracker.update(frame)
#
#     # Draw the bounding box
#     if success:
#         x, y, w, h = [int(v) for v in bbox]
#         cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
#     else:
#         cv2.putText(frame, "Tracking failed", (100, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 255), 2)
#
#     # Display the frame
#     cv2.imshow('Object Tracking', frame)
#
#     # Exit if 'q' is pressed
#     if cv2.waitKey(25) & 0xFF == ord('q'):
#         break
#
# # Release the video capture object and close windows
# cap.release()
# cv2.destroyAllWindows()
# ```
#
# #### **Explanation**:
# 1. The user selects a bounding box to track in the first frame.
# 2. The `tracker.update()` method tracks the object in subsequent frames.
# 3. The bounding box is drawn around the tracked object.
#
# ---
#
# ### **7.6 Code Example: Activity Recognition in Videos**
# Activity recognition involves identifying actions or events in a video. Let’s use a pre-trained model from TensorFlow Hub to recognize activities.
#
# ```python
# import tensorflow as tf
# import tensorflow_hub as hub
# import cv2
# import numpy as np
#
# # Load a pre-trained activity recognition model
# model = hub.load('https://tfhub.dev/deepmind/i3d-kinetics-400/1')
#
# # Open a video file
# video_path = 'example_video.mp4'
# cap = cv2.VideoCapture(video_path)
#
# # Process each frame
# frames = []
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # Resize and preprocess the frame
#     frame = cv2.resize(frame, (224, 224))
#     frame = frame / 255.0
#     frames.append(frame)
#
#     # Stop after collecting 16 frames (input size for I3D model)
#     if len(frames) == 16:
#         break
#
# # Convert frames to a numpy array
# frames = np.array(frames)
#
# # Perform activity recognition
# inputs = tf.expand_dims(frames, axis=0)
# outputs = model(inputs)
# predictions = tf.argmax(outputs, axis=-1).numpy()
#
# # Print the predicted activity
# print("Predicted Activity:", predictions)
#
# # Release the video capture object
# cap.release()
# ```
#
# #### **Explanation**:
# 1. The I3D model from TensorFlow Hub is used for activity recognition.
# 2. The video frames are preprocessed and fed into the model.
# 3. The model predicts the activity in the video.
#
# ---
#
# ### **7.7 Code Example: Video Summarization**
# Video summarization involves creating a shorter version of a video that captures its key events. Let’s use OpenCV to extract keyframes based on frame differences.
#
# ```python
# import cv2
# import numpy as np
#
# # Open a video file
# video_path = 'example_video.mp4'
# cap = cv2.VideoCapture(video_path)
#
# # Initialize variables
# prev_frame = None
# keyframes = []
#
# # Process each frame
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # Convert to grayscale
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
#     # Compare with the previous frame
#     if prev_frame is not None:
#         diff = cv2.absdiff(gray, prev_frame)
#         if diff.mean() > 10:  # Threshold for significant change
#             keyframes.append(frame)
#
#     prev_frame = gray
#
# # Save keyframes as a summary video
# if keyframes:
#     height, width, _ = keyframes[0].shape
#     out = cv2.VideoWriter('summary.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 10, (width, height))
#     for frame in keyframes:
#         out.write(frame)
#     out.release()
#
# # Release the video capture object
# cap.release()
# ```
#
# #### **Explanation**:
# 1. Keyframes are identified by comparing consecutive frames.
# 2. Frames with significant changes are saved as keyframes.
# 3. The keyframes are compiled into a summary video.
#
# ---
#
# ### **7.8 In Conclusion**
# - Video analysis extends image-based techniques to handle temporal data.
# - Tasks include object detection, tracking, activity recognition, and summarization.
# - Libraries like OpenCV and TensorFlow make it easy to implement video analysis pipelines.

# %%
! pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.9 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/Cars.mp4"
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/3000) /content/Cars.mp4: 384x640 2 persons, 9 cars, 60.0ms
# video 1/1 (frame 2/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 25.4ms
# video 1/1 (frame 3/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 25.3ms
# video 1/1 (frame 4/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 25.3ms
# video 1/1 (frame 5/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 25.3ms
# video 1/1 (frame 6/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 25.3ms
# video 1/1 (frame 7/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 25.3ms
# video 1/1 (frame 8/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 25.3ms
# video 1/1 (frame 9/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 17.8ms
# video 1/1 (frame 10/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 17.8ms
# video 1/1 (frame 11/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 17.8ms
# video 1/1 (frame 12/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 17.8ms
# video 1/1 (frame 13/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 17.8ms
# video 1/1 (frame 14/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 16.1ms
# video 1/1 (frame 15/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 16.1ms
# video 1/1 (frame 16/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 16.1ms
# video 1/1 (frame 17/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 16.0ms
# video 1/1 (frame 18/3000) /content/Cars.mp4: 384x640 8 cars, 1 truck, 16.0ms
# video 1/1 (frame 19/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 15.6ms
# video 1/1 (frame 20/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 15.2ms
# video 1/1 (frame 21/3000) /content/Cars.mp4: 384x640 2 persons, 9 cars, 1 truck, 15.2ms
# video 1/1 (frame 22/3000) /content/Cars.mp4: 384x640 2 persons, 9 cars, 1 truck, 14.8ms
# video 1/1 (frame 23/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 14.7ms
# video 1/1 (frame 24/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 14.8ms
# video 1/1 (frame 25/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 14.1ms
# video 1/1 (frame 26/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 14.1ms
# video 1/1 (frame 27/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 14.1ms
# video 1/1 (frame 28/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.9ms
# video 1/1 (frame 29/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.9ms
# video 1/1 (frame 30/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.9ms
# video 1/1 (frame 31/3000) /content/Cars.mp4: 384x640 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 32/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 1 truck, 13.3ms
# video 1/1 (frame 33/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 34/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 35/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 36/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 37/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 38/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 39/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 40/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 41/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 42/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 43/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 44/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 45/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 46/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 47/3000) /content/Cars.mp4: 384x640 2 persons, 9 cars, 1 truck, 13.0ms
# video 1/1 (frame 48/3000) /content/Cars.mp4: 384x640 3 persons, 9 cars, 1 truck, 13.0ms
# video 1/1 (frame 49/3000) /content/Cars.mp4: 384x640 3 persons, 9 cars, 1 truck, 13.0ms
# video 1/1 (frame 50/3000) /content/Cars.mp4: 384x640 2 persons, 9 cars, 1 truck, 13.0ms
# video 1/1 (frame 51/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 52/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 1 truck, 12.9ms
# video 1/1 (frame 53/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 54/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 55/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 13.0ms
# video 1/1 (frame 56/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 12.9ms
# video 1/1 (frame 57/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 58/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 59/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 60/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 61/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 62/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 63/3000) /content/Cars.mp4: 384x640 5 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 64/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 65/3000) /content/Cars.mp4: 384x640 5 persons, 8 cars, 13.0ms
# video 1/1 (frame 66/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 67/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 13.0ms
# video 1/1 (frame 68/3000) /content/Cars.mp4: 384x640 5 persons, 8 cars, 13.0ms
# video 1/1 (frame 69/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 13.0ms
# video 1/1 (frame 70/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 71/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 13.0ms
# video 1/1 (frame 72/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 12.9ms
# video 1/1 (frame 73/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 13.0ms
# video 1/1 (frame 74/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 75/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 76/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 14.3ms
# video 1/1 (frame 77/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 78/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 79/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 80/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 81/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 82/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 13.0ms
# video 1/1 (frame 83/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 13.0ms
# video 1/1 (frame 84/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 85/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 86/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 12.9ms
# video 1/1 (frame 87/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 88/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 89/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 90/3000) /content/Cars.mp4: 384x640 4 persons, 8 cars, 1 truck, 13.0ms
# video 1/1 (frame 91/3000) /content/Cars.mp4: 384x640 5 persons, 8 cars, 13.0ms
# video 1/1 (frame 92/3000) /content/Cars.mp4: 384x640 3 persons, 8 cars, 13.1ms
# video 1/1 (frame 93/3000) /content/Cars.mp4: 384x640 6 persons, 8 cars, 13.0ms
# video 1/1 (frame 94/3000) /content/Cars.mp4: 384x640 7 persons, 8 cars, 13.0ms
# video 1/1 (frame 95/3000) /content/Cars.mp4: 384x640 5 persons, 9 cars, 13.3ms
# video 1/1 (frame 96/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.3ms
# video 1/1 (frame 97/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.3ms
# video 1/1 (frame 98/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.0ms
# video 1/1 (frame 99/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.0ms
# video 1/1 (frame 100/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 1 truck, 13.1ms
# video 1/1 (frame 101/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.3ms
# video 1/1 (frame 102/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.3ms
# video 1/1 (frame 103/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.3ms
# video 1/1 (frame 104/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 12.9ms
# video 1/1 (frame 105/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 12.9ms
# video 1/1 (frame 106/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.2ms
# video 1/1 (frame 107/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 12.9ms
# video 1/1 (frame 108/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 12.9ms
# video 1/1 (frame 109/3000) /content/Cars.mp4: 384x640 8 persons, 7 cars, 12.9ms
# video 1/1 (frame 110/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 12.9ms
# video 1/1 (frame 111/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 12.9ms
# video 1/1 (frame 112/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 13.4ms
# video 1/1 (frame 113/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.0ms
# video 1/1 (frame 114/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 12.9ms
# video 1/1 (frame 115/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 12.9ms
# video 1/1 (frame 116/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 1 truck, 12.9ms
# video 1/1 (frame 117/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 12.9ms
# video 1/1 (frame 118/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 13.3ms
# video 1/1 (frame 119/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.3ms
# video 1/1 (frame 120/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.3ms
# video 1/1 (frame 121/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.1ms
# video 1/1 (frame 122/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.0ms
# video 1/1 (frame 123/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.0ms
# video 1/1 (frame 124/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 13.1ms
# video 1/1 (frame 125/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 13.0ms
# video 1/1 (frame 126/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.0ms
# video 1/1 (frame 127/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 13.1ms
# video 1/1 (frame 128/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 13.0ms
# video 1/1 (frame 129/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 13.1ms
# video 1/1 (frame 130/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 13.0ms
# video 1/1 (frame 131/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 13.1ms
# video 1/1 (frame 132/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 13.0ms
# video 1/1 (frame 133/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 13.1ms
# video 1/1 (frame 134/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.0ms
# video 1/1 (frame 135/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 15.8ms
# video 1/1 (frame 136/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.4ms
# video 1/1 (frame 137/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 13.4ms
# video 1/1 (frame 138/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.2ms
# video 1/1 (frame 139/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 13.2ms
# video 1/1 (frame 140/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.2ms
# video 1/1 (frame 141/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.3ms
# video 1/1 (frame 142/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.3ms
# video 1/1 (frame 143/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.3ms
# video 1/1 (frame 144/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 145/3000) /content/Cars.mp4: 384x640 5 persons, 6 cars, 13.0ms
# video 1/1 (frame 146/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 147/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 148/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 13.0ms
# video 1/1 (frame 149/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.0ms
# video 1/1 (frame 150/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 151/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.1ms
# video 1/1 (frame 152/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 153/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 154/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.0ms
# video 1/1 (frame 155/3000) /content/Cars.mp4: 384x640 5 persons, 6 cars, 1 truck, 13.5ms
# video 1/1 (frame 156/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 1 truck, 13.1ms
# video 1/1 (frame 157/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 1 truck, 13.1ms
# video 1/1 (frame 158/3000) /content/Cars.mp4: 384x640 5 persons, 6 cars, 13.1ms
# video 1/1 (frame 159/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 13.1ms
# video 1/1 (frame 160/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.1ms
# video 1/1 (frame 161/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 13.1ms
# video 1/1 (frame 162/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 13.1ms
# video 1/1 (frame 163/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 13.3ms
# video 1/1 (frame 164/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 13.0ms
# video 1/1 (frame 165/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.0ms
# video 1/1 (frame 166/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.1ms
# video 1/1 (frame 167/3000) /content/Cars.mp4: 384x640 5 persons, 5 cars, 13.0ms
# video 1/1 (frame 168/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.0ms
# video 1/1 (frame 169/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 13.1ms
# video 1/1 (frame 170/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.1ms
# video 1/1 (frame 171/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.0ms
# video 1/1 (frame 172/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 16.4ms
# video 1/1 (frame 173/3000) /content/Cars.mp4: 384x640 5 persons, 5 cars, 13.0ms
# video 1/1 (frame 174/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.1ms
# video 1/1 (frame 175/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.0ms
# video 1/1 (frame 176/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 13.0ms
# video 1/1 (frame 177/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.1ms
# video 1/1 (frame 178/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 13.1ms
# video 1/1 (frame 179/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 13.0ms
# video 1/1 (frame 180/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 13.1ms
# video 1/1 (frame 181/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.3ms
# video 1/1 (frame 182/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 183/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 14.2ms
# video 1/1 (frame 184/3000) /content/Cars.mp4: 384x640 6 persons, 5 cars, 1 truck, 15.5ms
# video 1/1 (frame 185/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 15.6ms
# video 1/1 (frame 186/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 15.1ms
# video 1/1 (frame 187/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 16.0ms
# video 1/1 (frame 188/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 16.1ms
# video 1/1 (frame 189/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 15.9ms
# video 1/1 (frame 190/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 15.6ms
# video 1/1 (frame 191/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 15.6ms
# video 1/1 (frame 192/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 train, 15.5ms
# video 1/1 (frame 193/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 15.8ms
# video 1/1 (frame 194/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 15.5ms
# video 1/1 (frame 195/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 15.5ms
# video 1/1 (frame 196/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 16.7ms
# video 1/1 (frame 197/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 16.0ms
# video 1/1 (frame 198/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 truck, 15.9ms
# video 1/1 (frame 199/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 15.9ms
# video 1/1 (frame 200/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 16.1ms
# video 1/1 (frame 201/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 16.1ms
# video 1/1 (frame 202/3000) /content/Cars.mp4: 384x640 4 persons, 4 cars, 16.1ms
# video 1/1 (frame 203/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 16.0ms
# video 1/1 (frame 204/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 16.0ms
# video 1/1 (frame 205/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 truck, 15.6ms
# video 1/1 (frame 206/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 truck, 15.2ms
# video 1/1 (frame 207/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 truck, 15.2ms
# video 1/1 (frame 208/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 15.0ms
# video 1/1 (frame 209/3000) /content/Cars.mp4: 384x640 4 persons, 4 cars, 14.9ms
# video 1/1 (frame 210/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 14.9ms
# video 1/1 (frame 211/3000) /content/Cars.mp4: 384x640 5 persons, 4 cars, 14.1ms
# video 1/1 (frame 212/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 train, 14.1ms
# video 1/1 (frame 213/3000) /content/Cars.mp4: 384x640 5 persons, 4 cars, 1 train, 14.1ms
# video 1/1 (frame 214/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 train, 13.9ms
# video 1/1 (frame 215/3000) /content/Cars.mp4: 384x640 5 persons, 4 cars, 1 train, 13.9ms
# video 1/1 (frame 216/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 train, 13.9ms
# video 1/1 (frame 217/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 train, 13.4ms
# video 1/1 (frame 218/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 train, 13.4ms
# video 1/1 (frame 219/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 train, 13.7ms
# video 1/1 (frame 220/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 train, 13.2ms
# video 1/1 (frame 221/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 13.2ms
# video 1/1 (frame 222/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 train, 13.2ms
# video 1/1 (frame 223/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 train, 13.3ms
# video 1/1 (frame 224/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 train, 13.3ms
# video 1/1 (frame 225/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 traffic light, 13.3ms
# video 1/1 (frame 226/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 1 traffic light, 13.0ms
# video 1/1 (frame 227/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 228/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 1 traffic light, 13.1ms
# video 1/1 (frame 229/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 13.1ms
# video 1/1 (frame 230/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 13.1ms
# video 1/1 (frame 231/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 232/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 1 traffic light, 13.0ms
# video 1/1 (frame 233/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 234/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 train, 1 truck, 13.0ms
# video 1/1 (frame 235/3000) /content/Cars.mp4: 384x640 4 persons, 7 cars, 1 truck, 1 traffic light, 13.0ms
# video 1/1 (frame 236/3000) /content/Cars.mp4: 384x640 5 persons, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 237/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.1ms
# video 1/1 (frame 238/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 1 truck, 13.0ms
# video 1/1 (frame 239/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 train, 1 truck, 13.3ms
# video 1/1 (frame 240/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 1 train, 1 truck, 13.1ms
# video 1/1 (frame 241/3000) /content/Cars.mp4: 384x640 4 persons, 6 cars, 1 truck, 13.0ms
# video 1/1 (frame 242/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 243/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 1 truck, 13.0ms
# video 1/1 (frame 244/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 13.1ms
# video 1/1 (frame 245/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.0ms
# video 1/1 (frame 246/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 13.1ms
# video 1/1 (frame 247/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 12.9ms
# video 1/1 (frame 248/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 12.9ms
# video 1/1 (frame 249/3000) /content/Cars.mp4: 384x640 4 persons, 5 cars, 1 truck, 1 traffic light, 12.9ms
# video 1/1 (frame 250/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 12.8ms
# video 1/1 (frame 251/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 252/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 253/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 254/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 255/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 256/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 257/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 258/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 259/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 260/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 261/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 262/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 263/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 264/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 265/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 266/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 267/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.8ms
# video 1/1 (frame 268/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.8ms
# video 1/1 (frame 269/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.8ms
# video 1/1 (frame 270/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 12.8ms
# video 1/1 (frame 271/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 272/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 273/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 12.8ms
# video 1/1 (frame 274/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 275/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 276/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 277/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 278/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 279/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 280/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 281/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 traffic light, 12.8ms
# video 1/1 (frame 282/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 1 traffic light, 12.8ms
# video 1/1 (frame 283/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.6ms
# video 1/1 (frame 284/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 1 traffic light, 12.3ms
# video 1/1 (frame 285/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 1 traffic light, 12.3ms
# video 1/1 (frame 286/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.3ms
# video 1/1 (frame 287/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 288/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 289/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.3ms
# video 1/1 (frame 290/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 291/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 292/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.3ms
# video 1/1 (frame 293/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 2 trucks, 12.1ms
# video 1/1 (frame 294/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.1ms
# video 1/1 (frame 295/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.1ms
# video 1/1 (frame 296/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 12.0ms
# video 1/1 (frame 297/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 298/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 11.9ms
# video 1/1 (frame 299/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 12.0ms
# video 1/1 (frame 300/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 301/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 12.0ms
# video 1/1 (frame 302/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 17.1ms
# video 1/1 (frame 303/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 304/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 305/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 306/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 307/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 308/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 2 trucks, 12.5ms
# video 1/1 (frame 309/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 310/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 311/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 312/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 313/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 12.0ms
# video 1/1 (frame 314/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 12.0ms
# video 1/1 (frame 315/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 12.0ms
# video 1/1 (frame 316/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 317/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 318/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 319/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 1 truck, 11.9ms
# video 1/1 (frame 320/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 1 truck, 11.9ms
# video 1/1 (frame 321/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 11.9ms
# video 1/1 (frame 322/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 11.8ms
# video 1/1 (frame 323/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.8ms
# video 1/1 (frame 324/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.8ms
# video 1/1 (frame 325/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 2 trucks, 11.9ms
# video 1/1 (frame 326/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 2 trucks, 11.8ms
# video 1/1 (frame 327/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 2 trucks, 11.8ms
# video 1/1 (frame 328/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 2 trucks, 11.7ms
# video 1/1 (frame 329/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 2 trucks, 11.7ms
# video 1/1 (frame 330/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 2 trucks, 11.7ms
# video 1/1 (frame 331/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 11.7ms
# video 1/1 (frame 332/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 11.7ms
# video 1/1 (frame 333/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 334/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 335/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 13.9ms
# video 1/1 (frame 336/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 337/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 338/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 339/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 340/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.9ms
# video 1/1 (frame 341/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 11.7ms
# video 1/1 (frame 342/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 11.7ms
# video 1/1 (frame 343/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 344/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.6ms
# video 1/1 (frame 345/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 346/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 347/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 348/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 349/3000) /content/Cars.mp4: 384x640 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 350/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 351/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.9ms
# video 1/1 (frame 352/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 11.7ms
# video 1/1 (frame 353/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 354/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 355/3000) /content/Cars.mp4: 384x640 3 persons, 5 cars, 11.7ms
# video 1/1 (frame 356/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 357/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 358/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 359/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.6ms
# video 1/1 (frame 360/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 2 trucks, 11.8ms
# video 1/1 (frame 361/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 3 trucks, 11.7ms
# video 1/1 (frame 362/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 3 trucks, 11.8ms
# video 1/1 (frame 363/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 3 trucks, 11.7ms
# video 1/1 (frame 364/3000) /content/Cars.mp4: 384x640 5 cars, 3 trucks, 11.7ms
# video 1/1 (frame 365/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 3 trucks, 11.7ms
# video 1/1 (frame 366/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 3 trucks, 11.7ms
# video 1/1 (frame 367/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.8ms
# video 1/1 (frame 368/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 3 trucks, 11.7ms
# video 1/1 (frame 369/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 2 trucks, 11.7ms
# video 1/1 (frame 370/3000) /content/Cars.mp4: 384x640 2 persons, 3 cars, 2 trucks, 11.7ms
# video 1/1 (frame 371/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.6ms
# video 1/1 (frame 372/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 373/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 374/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 375/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.8ms
# video 1/1 (frame 376/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 377/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 378/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.7ms
# video 1/1 (frame 379/3000) /content/Cars.mp4: 384x640 3 persons, 4 cars, 2 trucks, 11.6ms
# video 1/1 (frame 380/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 381/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.5ms
# video 1/1 (frame 382/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.6ms
# video 1/1 (frame 383/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.5ms
# video 1/1 (frame 384/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 385/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 11.5ms
# video 1/1 (frame 386/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 11.5ms
# video 1/1 (frame 387/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 388/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 389/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 390/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.7ms
# video 1/1 (frame 391/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 392/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 393/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 394/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 395/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 396/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 397/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 398/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 399/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 400/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.9ms
# video 1/1 (frame 401/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 402/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 403/3000) /content/Cars.mp4: 384x640 3 persons, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 404/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 2 trucks, 11.7ms
# video 1/1 (frame 405/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 406/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 2 trucks, 11.7ms
# video 1/1 (frame 407/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 408/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 2 trucks, 11.5ms
# video 1/1 (frame 409/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 410/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 411/3000) /content/Cars.mp4: 384x640 2 persons, 4 cars, 2 trucks, 11.5ms
# video 1/1 (frame 412/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.5ms
# video 1/1 (frame 413/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 414/3000) /content/Cars.mp4: 384x640 2 persons, 6 cars, 1 truck, 11.5ms
# video 1/1 (frame 415/3000) /content/Cars.mp4: 384x640 2 persons, 5 cars, 1 truck, 11.5ms
# video 1/1 (frame 416/3000) /content/Cars.mp4: 384x640 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 417/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.5ms
# video 1/1 (frame 418/3000) /content/Cars.mp4: 384x640 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 419/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 420/3000) /content/Cars.mp4: 384x640 5 cars, 2 trucks, 11.5ms
# video 1/1 (frame 421/3000) /content/Cars.mp4: 384x640 5 cars, 11.5ms
# video 1/1 (frame 422/3000) /content/Cars.mp4: 384x640 5 cars, 11.5ms
# video 1/1 (frame 423/3000) /content/Cars.mp4: 384x640 5 cars, 11.5ms
# video 1/1 (frame 424/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 425/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.5ms
# video 1/1 (frame 426/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.5ms
# video 1/1 (frame 427/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 428/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 429/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.5ms
# video 1/1 (frame 430/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.6ms
# video 1/1 (frame 431/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 432/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.9ms
# video 1/1 (frame 433/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 434/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 14.5ms
# video 1/1 (frame 435/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 436/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 437/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 438/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 439/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 440/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 441/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 442/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.6ms
# video 1/1 (frame 443/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 444/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 445/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 446/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 447/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 448/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 449/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 450/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 451/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 452/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 453/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 454/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 455/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 456/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 457/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 458/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.5ms
# video 1/1 (frame 459/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 460/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 461/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 462/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 463/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 464/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 465/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 466/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.0ms
# video 1/1 (frame 467/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 12.0ms
# video 1/1 (frame 468/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 12.5ms
# video 1/1 (frame 469/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 470/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 471/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 472/3000) /content/Cars.mp4: 384x640 4 cars, 11.7ms
# video 1/1 (frame 473/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 474/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.5ms
# video 1/1 (frame 475/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 476/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.5ms
# video 1/1 (frame 477/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.5ms
# video 1/1 (frame 478/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 479/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.4ms
# video 1/1 (frame 480/3000) /content/Cars.mp4: 384x640 5 cars, 11.4ms
# video 1/1 (frame 481/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 11.4ms
# video 1/1 (frame 482/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 483/3000) /content/Cars.mp4: 384x640 4 cars, 11.5ms
# video 1/1 (frame 484/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 11.4ms
# video 1/1 (frame 485/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 486/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 487/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.6ms
# video 1/1 (frame 488/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.4ms
# video 1/1 (frame 489/3000) /content/Cars.mp4: 384x640 3 cars, 2 trucks, 11.4ms
# video 1/1 (frame 490/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 491/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 492/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 493/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 494/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 495/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 496/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 497/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.4ms
# video 1/1 (frame 498/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 499/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 500/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 501/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 502/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 503/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 504/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 505/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.7ms
# video 1/1 (frame 506/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 507/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 508/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 509/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 510/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 511/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 512/3000) /content/Cars.mp4: 384x640 4 cars, 11.4ms
# video 1/1 (frame 513/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 514/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 515/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 13.3ms
# video 1/1 (frame 516/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.7ms
# video 1/1 (frame 517/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.4ms
# video 1/1 (frame 518/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 12.8ms
# video 1/1 (frame 519/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 520/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 521/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 13.5ms
# video 1/1 (frame 522/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 523/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.4ms
# video 1/1 (frame 524/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 525/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 526/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 527/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 528/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 529/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 11.4ms
# video 1/1 (frame 530/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.1ms
# video 1/1 (frame 531/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 14.2ms
# video 1/1 (frame 532/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 15.5ms
# video 1/1 (frame 533/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.6ms
# video 1/1 (frame 534/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 12.5ms
# video 1/1 (frame 535/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 train, 1 truck, 15.0ms
# video 1/1 (frame 536/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.8ms
# video 1/1 (frame 537/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.8ms
# video 1/1 (frame 538/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.7ms
# video 1/1 (frame 539/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.6ms
# video 1/1 (frame 540/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.1ms
# video 1/1 (frame 541/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.1ms
# video 1/1 (frame 542/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.9ms
# video 1/1 (frame 543/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 12.9ms
# video 1/1 (frame 544/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.4ms
# video 1/1 (frame 545/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.4ms
# video 1/1 (frame 546/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.3ms
# video 1/1 (frame 547/3000) /content/Cars.mp4: 384x640 1 person, 4 cars, 1 truck, 13.2ms
# video 1/1 (frame 548/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.2ms
# video 1/1 (frame 549/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.6ms
# video 1/1 (frame 550/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 13.6ms
# video 1/1 (frame 551/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 truck, 14.9ms
# video 1/1 (frame 552/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 15.9ms
# video 1/1 (frame 553/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 13.9ms
# video 1/1 (frame 554/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 13.8ms
# video 1/1 (frame 555/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 14.8ms
# video 1/1 (frame 556/3000) /content/Cars.mp4: 384x640 1 person, 3 cars, 1 train, 1 truck, 13.6ms
# video 1/1 (frame 557/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 13.6ms
# video 1/1 (frame 558/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 truck, 14.1ms
# video 1/1 (frame 559/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 truck, 14.1ms
# video 1/1 (frame 560/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 truck, 13.7ms
# video 1/1 (frame 561/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 13.8ms
# video 1/1 (frame 562/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 14.4ms
# video 1/1 (frame 563/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 14.4ms
# video 1/1 (frame 564/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 14.3ms
# video 1/1 (frame 565/3000) /content/Cars.mp4: 384x640 1 person, 2 cars, 1 train, 1 truck, 14.0ms
# ...
# video 1/1 (frame 2799/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.3ms
# video 1/1 (frame 2800/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 2801/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 11.9ms
# video 1/1 (frame 2802/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.2ms
# video 1/1 (frame 2803/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 11.9ms
# video 1/1 (frame 2804/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.1ms
# video 1/1 (frame 2805/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 11.9ms
# video 1/1 (frame 2806/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.2ms
# video 1/1 (frame 2807/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 2808/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.2ms
# video 1/1 (frame 2809/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 2810/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.2ms
# video 1/1 (frame 2811/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.0ms
# video 1/1 (frame 2812/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.1ms
# video 1/1 (frame 2813/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 11.9ms
# video 1/1 (frame 2814/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.0ms
# video 1/1 (frame 2815/3000) /content/Cars.mp4: 384x640 2 cars, 1 truck, 12.0ms
# video 1/1 (frame 2816/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.9ms
# video 1/1 (frame 2817/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.9ms
# video 1/1 (frame 2818/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 12.0ms
# video 1/1 (frame 2819/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 12.2ms
# video 1/1 (frame 2820/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.6ms
# video 1/1 (frame 2821/3000) /content/Cars.mp4: 384x640 3 cars, 12.1ms
# video 1/1 (frame 2822/3000) /content/Cars.mp4: 384x640 3 cars, 1 truck, 11.6ms
# video 1/1 (frame 2823/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.5ms
# video 1/1 (frame 2824/3000) /content/Cars.mp4: 384x640 4 cars, 1 truck, 12.6ms
# video 1/1 (frame 2825/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 2826/3000) /content/Cars.mp4: 384x640 4 cars, 12.1ms
# video 1/1 (frame 2827/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2828/3000) /content/Cars.mp4: 384x640 4 cars, 12.2ms
# video 1/1 (frame 2829/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2830/3000) /content/Cars.mp4: 384x640 4 cars, 12.3ms
# video 1/1 (frame 2831/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2832/3000) /content/Cars.mp4: 384x640 4 cars, 12.1ms
# video 1/1 (frame 2833/3000) /content/Cars.mp4: 384x640 4 cars, 11.7ms
# video 1/1 (frame 2834/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 2835/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2836/3000) /content/Cars.mp4: 384x640 5 cars, 11.8ms
# video 1/1 (frame 2837/3000) /content/Cars.mp4: 384x640 5 cars, 11.6ms
# video 1/1 (frame 2838/3000) /content/Cars.mp4: 384x640 5 cars, 11.7ms
# video 1/1 (frame 2839/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2840/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2841/3000) /content/Cars.mp4: 384x640 4 cars, 2 trucks, 11.6ms
# video 1/1 (frame 2842/3000) /content/Cars.mp4: 384x640 5 cars, 11.7ms
# video 1/1 (frame 2843/3000) /content/Cars.mp4: 384x640 5 cars, 11.8ms
# video 1/1 (frame 2844/3000) /content/Cars.mp4: 384x640 5 cars, 11.6ms
# video 1/1 (frame 2845/3000) /content/Cars.mp4: 384x640 4 cars, 11.8ms
# video 1/1 (frame 2846/3000) /content/Cars.mp4: 384x640 4 cars, 11.6ms
# video 1/1 (frame 2847/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.7ms
# video 1/1 (frame 2848/3000) /content/Cars.mp4: 384x640 5 cars, 11.6ms
# video 1/1 (frame 2849/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 11.8ms
# video 1/1 (frame 2850/3000) /content/Cars.mp4: 384x640 6 cars, 11.6ms
# video 1/1 (frame 2851/3000) /content/Cars.mp4: 384x640 5 cars, 12.2ms
# video 1/1 (frame 2852/3000) /content/Cars.mp4: 384x640 6 cars, 11.6ms
# video 1/1 (frame 2853/3000) /content/Cars.mp4: 384x640 6 cars, 12.0ms
# video 1/1 (frame 2854/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2855/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2856/3000) /content/Cars.mp4: 384x640 6 cars, 11.6ms
# video 1/1 (frame 2857/3000) /content/Cars.mp4: 384x640 6 cars, 13.1ms
# video 1/1 (frame 2858/3000) /content/Cars.mp4: 384x640 6 cars, 11.6ms
# video 1/1 (frame 2859/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 12.2ms
# video 1/1 (frame 2860/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2861/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2862/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2863/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.6ms
# video 1/1 (frame 2864/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 1 truck, 12.0ms
# video 1/1 (frame 2865/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 11.8ms
# video 1/1 (frame 2866/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 12.0ms
# video 1/1 (frame 2867/3000) /content/Cars.mp4: 384x640 6 cars, 11.8ms
# video 1/1 (frame 2868/3000) /content/Cars.mp4: 384x640 6 cars, 11.8ms
# video 1/1 (frame 2869/3000) /content/Cars.mp4: 384x640 6 cars, 12.2ms
# video 1/1 (frame 2870/3000) /content/Cars.mp4: 384x640 6 cars, 11.8ms
# video 1/1 (frame 2871/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.9ms
# video 1/1 (frame 2872/3000) /content/Cars.mp4: 384x640 5 cars, 1 truck, 11.8ms
# video 1/1 (frame 2873/3000) /content/Cars.mp4: 384x640 1 person, 5 cars, 1 truck, 11.8ms
# video 1/1 (frame 2874/3000) /content/Cars.mp4: 384x640 5 cars, 2 trucks, 11.9ms
# video 1/1 (frame 2875/3000) /content/Cars.mp4: 384x640 6 cars, 1 truck, 11.8ms
# video 1/1 (frame 2876/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.1ms
# video 1/1 (frame 2877/3000) /content/Cars.mp4: 384x640 5 cars, 11.8ms
# video 1/1 (frame 2878/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2879/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2880/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2881/3000) /content/Cars.mp4: 384x640 7 cars, 11.9ms
# video 1/1 (frame 2882/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2883/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 2 trucks, 12.4ms
# video 1/1 (frame 2884/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2885/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2886/3000) /content/Cars.mp4: 384x640 7 cars, 12.0ms
# video 1/1 (frame 2887/3000) /content/Cars.mp4: 384x640 7 cars, 2 trucks, 11.8ms
# video 1/1 (frame 2888/3000) /content/Cars.mp4: 384x640 7 cars, 2 trucks, 12.2ms
# video 1/1 (frame 2889/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 12.6ms
# video 1/1 (frame 2890/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2891/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 11.9ms
# video 1/1 (frame 2892/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2893/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2894/3000) /content/Cars.mp4: 384x640 7 cars, 11.9ms
# video 1/1 (frame 2895/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2896/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2897/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2898/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2899/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2900/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2901/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.9ms
# video 1/1 (frame 2902/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2903/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.2ms
# video 1/1 (frame 2904/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2905/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.1ms
# video 1/1 (frame 2906/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2907/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2908/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2909/3000) /content/Cars.mp4: 384x640 7 cars, 11.7ms
# video 1/1 (frame 2910/3000) /content/Cars.mp4: 384x640 7 cars, 11.9ms
# video 1/1 (frame 2911/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2912/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.2ms
# video 1/1 (frame 2913/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2914/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 11.7ms
# video 1/1 (frame 2915/3000) /content/Cars.mp4: 384x640 8 cars, 12.2ms
# video 1/1 (frame 2916/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2917/3000) /content/Cars.mp4: 384x640 7 cars, 11.8ms
# video 1/1 (frame 2918/3000) /content/Cars.mp4: 384x640 7 cars, 11.7ms
# video 1/1 (frame 2919/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2920/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.0ms
# video 1/1 (frame 2921/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.8ms
# video 1/1 (frame 2922/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2923/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2924/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.0ms
# video 1/1 (frame 2925/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 1 truck, 11.7ms
# video 1/1 (frame 2926/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.7ms
# video 1/1 (frame 2927/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.9ms
# video 1/1 (frame 2928/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.7ms
# video 1/1 (frame 2929/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2930/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2931/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2932/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.0ms
# video 1/1 (frame 2933/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.8ms
# video 1/1 (frame 2934/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 11.7ms
# video 1/1 (frame 2935/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.1ms
# video 1/1 (frame 2936/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2937/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2938/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 12.0ms
# video 1/1 (frame 2939/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2940/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.9ms
# video 1/1 (frame 2941/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.7ms
# video 1/1 (frame 2942/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 11.7ms
# video 1/1 (frame 2943/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 12.0ms
# video 1/1 (frame 2944/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.7ms
# video 1/1 (frame 2945/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2946/3000) /content/Cars.mp4: 384x640 2 persons, 8 cars, 11.9ms
# video 1/1 (frame 2947/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 11.7ms
# video 1/1 (frame 2948/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2949/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.7ms
# video 1/1 (frame 2950/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.8ms
# video 1/1 (frame 2951/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.7ms
# video 1/1 (frame 2952/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 11.7ms
# video 1/1 (frame 2953/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2954/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 12.2ms
# video 1/1 (frame 2955/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 11.7ms
# video 1/1 (frame 2956/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.7ms
# video 1/1 (frame 2957/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.1ms
# video 1/1 (frame 2958/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 11.7ms
# video 1/1 (frame 2959/3000) /content/Cars.mp4: 384x640 2 persons, 7 cars, 11.8ms
# video 1/1 (frame 2960/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 11.8ms
# video 1/1 (frame 2961/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 11.7ms
# video 1/1 (frame 2962/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.1ms
# video 1/1 (frame 2963/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.7ms
# video 1/1 (frame 2964/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.7ms
# video 1/1 (frame 2965/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.7ms
# video 1/1 (frame 2966/3000) /content/Cars.mp4: 384x640 3 persons, 7 cars, 12.7ms
# video 1/1 (frame 2967/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 12.7ms
# video 1/1 (frame 2968/3000) /content/Cars.mp4: 384x640 7 cars, 12.7ms
# video 1/1 (frame 2969/3000) /content/Cars.mp4: 384x640 7 cars, 12.6ms
# video 1/1 (frame 2970/3000) /content/Cars.mp4: 384x640 8 cars, 12.6ms
# video 1/1 (frame 2971/3000) /content/Cars.mp4: 384x640 8 cars, 12.6ms
# video 1/1 (frame 2972/3000) /content/Cars.mp4: 384x640 8 cars, 12.6ms
# video 1/1 (frame 2973/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 12.5ms
# video 1/1 (frame 2974/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.6ms
# video 1/1 (frame 2975/3000) /content/Cars.mp4: 384x640 7 cars, 12.8ms
# video 1/1 (frame 2976/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.8ms
# video 1/1 (frame 2977/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 12.8ms
# video 1/1 (frame 2978/3000) /content/Cars.mp4: 384x640 7 cars, 12.7ms
# video 1/1 (frame 2979/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 12.7ms
# video 1/1 (frame 2980/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 12.7ms
# video 1/1 (frame 2981/3000) /content/Cars.mp4: 384x640 1 person, 6 cars, 12.7ms
# video 1/1 (frame 2982/3000) /content/Cars.mp4: 384x640 7 cars, 14.3ms
# video 1/1 (frame 2983/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.7ms
# video 1/1 (frame 2984/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 12.9ms
# video 1/1 (frame 2985/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 18.4ms
# video 1/1 (frame 2986/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 19.3ms
# video 1/1 (frame 2987/3000) /content/Cars.mp4: 384x640 1 person, 7 cars, 1 truck, 13.0ms
# video 1/1 (frame 2988/3000) /content/Cars.mp4: 384x640 7 cars, 1 truck, 12.9ms
# video 1/1 (frame 2989/3000) /content/Cars.mp4: 384x640 8 cars, 1 truck, 12.8ms
# video 1/1 (frame 2990/3000) /content/Cars.mp4: 384x640 8 cars, 1 truck, 12.8ms
# video 1/1 (frame 2991/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.2ms
# video 1/1 (frame 2992/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 13.2ms
# video 1/1 (frame 2993/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 13.0ms
# video 1/1 (frame 2994/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 13.1ms
# video 1/1 (frame 2995/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 13.4ms
# video 1/1 (frame 2996/3000) /content/Cars.mp4: 384x640 1 person, 9 cars, 13.5ms
# video 1/1 (frame 2997/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 2998/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 1 truck, 13.3ms
# video 1/1 (frame 2999/3000) /content/Cars.mp4: 384x640 9 cars, 1 truck, 13.4ms
# video 1/1 (frame 3000/3000) /content/Cars.mp4: 384x640 1 person, 8 cars, 13.7ms
# Speed: 2.2ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ffmpeg -i {"/content/runs/detect/predict/Cars.avi"} -vcodec libx264 {"final.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from '/content/runs/detect/predict/Cars.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:00.00, start: 0.000000, bitrate: 54900 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 1280x720, 54906 kb/s, 50 fps, 50 tbr, 50 tbn, 50 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56f91e33eb80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x56f91e33eb80] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x56f91e33eb80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'final.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 1280x720, q=2-31, 50 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 3000 fps= 22 q=-1.0 Lsize=   22313kB time=00:00:59.94 bitrate=3049.6kbits/s speed=0.434x
# video:22277kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.162557%
# [libx264 @ 0x56f91e33eb80] frame I:12    Avg QP:20.83  size:108779
# [libx264 @ 0x56f91e33eb80] frame P:759   Avg QP:23.83  size: 19846
# [libx264 @ 0x56f91e33eb80] frame B:2229  Avg QP:28.54  size:  2890
# [libx264 @ 0x56f91e33eb80] consecutive B-frames:  0.6%  0.7%  1.3% 97.5%
# [libx264 @ 0x56f91e33eb80] mb I  I16..4:  4.1% 85.6% 10.3%
# [libx264 @ 0x56f91e33eb80] mb P  I16..4:  1.3%  7.8%  0.9%  P16..4: 35.9% 15.0% 12.6%  0.0%  0.0%    skip:26.5%
# [libx264 @ 0x56f91e33eb80] mb B  I16..4:  0.2%  0.2%  0.2%  B16..8: 30.5%  3.0%  0.6%  direct: 0.4%  skip:64.8%  L0:44.6% L1:52.7% BI: 2.7%
# [libx264 @ 0x56f91e33eb80] 8x8 transform intra:72.9% inter:71.8%
# [libx264 @ 0x56f91e33eb80] coded y,uvDC,uvAC intra: 64.0% 72.1% 17.1% inter: 8.4% 11.1% 1.4%
# [libx264 @ 0x56f91e33eb80] i16 v,h,dc,p: 25% 50% 13% 11%
# [libx264 @ 0x56f91e33eb80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 23% 49%  1%  3%  2%  4%  1%  2%
# [libx264 @ 0x56f91e33eb80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 35% 12%  4%  4%  4%  5%  5%  4%
# [libx264 @ 0x56f91e33eb80] i8c dc,h,v,p: 45% 31% 21%  4%
# [libx264 @ 0x56f91e33eb80] Weighted P-Frames: Y:0.8% UV:0.0%
# [libx264 @ 0x56f91e33eb80] ref P L0: 59.2% 16.4% 17.6%  6.8%  0.0%
# [libx264 @ 0x56f91e33eb80] ref B L0: 84.0% 12.7%  3.3%
# [libx264 @ 0x56f91e33eb80] ref B L1: 92.4%  7.6%
# [libx264 @ 0x56f91e33eb80] kb/s:3041.47

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.74-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.74-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 25.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.74 ultralytics-thop-2.0.14

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow # Import the cv2_imshow function

# Load a pre-trained YOLO model
model = YOLO('yolov8n.pt')

# Open a video file
video_path = '/content/Cars.mp4'
cap = cv2.VideoCapture(video_path)

# Process each frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform object detection
    results = model(frame)

    # Visualize the results
    annotated_frame = results[0].plot()

    # Display the annotated frame using cv2_imshow
    cv2_imshow(annotated_frame)

    # Exit if 'q' is pressed
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# Release the video capture object and close windows
cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow  # If you still want to preview frames

# Load a pre-trained YOLO model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = '/content/Cars.mp4'  # Make sure the path is correct
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error opening video: {video_path}")
    exit()

# Get video properties (width, height, FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Or use *'XVID' for .avi
output_path = '/content/output_video.mp4'  # Path to save the new video
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))  # Use original width and height

# Process each frame and write to the output video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform object detection
    results = model(frame)

    # Visualize the results
    annotated_frame = results[0].plot()

    # Write the annotated frame to the output video
    out.write(annotated_frame)

    # Preview (optional - comment out if not needed)
    # cv2_imshow(annotated_frame)  # Preview if you want to see frame by frame
    # if cv2.waitKey(1) & 0xFF == ord('q'): # Break if 'q' is pressed during preview
    #     break # Break the loop

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video saved to: {output_path}")

# Display the saved video (if needed, in a new cell)
# from IPython.display import HTML
# from base64 import b64encode

# mp4 = open(output_path,'rb').read()
# data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# HTML("""
# <video width=640 controls>
#       <source src="%s" type="video/mp4">
# </video>
# """ % data_url)

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.74-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.74-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.74 ultralytics-thop-2.0.14

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow  # If you still want to preview frames

# Load a pre-trained YOLO model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = '/content/Cars.mp4'  # Make sure the path is correct
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error opening video: {video_path}")
    exit()

# Get video properties (width, height, FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Or use *'XVID' for .avi
output_path = '/content/output_video.mp4'  # Path to save the new video
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))  # Use original width and height

# Process each frame and write to the output video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform object detection
    results = model(frame)

    # Visualize the results
    annotated_frame = results[0].plot()

    # Write the annotated frame to the output video
    out.write(annotated_frame)

    # Preview (optional - comment out if not needed)
    # cv2_imshow(annotated_frame)  # Preview if you want to see frame by frame
    # if cv2.waitKey(1) & 0xFF == ord('q'): # Break if 'q' is pressed during preview
    #     break # Break the loop

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video saved to: {output_path}")

# Display the saved video (if needed, in a new cell)
# from IPython.display import HTML
# from base64 import b64encode

# mp4 = open(output_path,'rb').read()
# data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# HTML("""
# <video width=640 controls>
#       <source src="%s" type="video/mp4">
# </video>
# """ % data_url)
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 4.9ms preprocess, 157.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 151.9ms
# Speed: 6.6ms preprocess, 151.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 159.6ms
# Speed: 5.2ms preprocess, 159.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 149.8ms
# Speed: 5.4ms preprocess, 149.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 152.0ms
# Speed: 6.1ms preprocess, 152.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 164.9ms
# Speed: 5.0ms preprocess, 164.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 148.8ms
# Speed: 5.1ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.5ms
# Speed: 4.7ms preprocess, 162.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 151.0ms
# Speed: 5.0ms preprocess, 151.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 157.8ms
# Speed: 4.8ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 142.0ms
# Speed: 4.7ms preprocess, 142.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 165.9ms
# Speed: 3.3ms preprocess, 165.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 158.9ms
# Speed: 3.4ms preprocess, 158.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 158.4ms
# Speed: 5.4ms preprocess, 158.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 168.1ms
# Speed: 5.1ms preprocess, 168.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 160.6ms
# Speed: 5.2ms preprocess, 160.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 166.1ms
# Speed: 6.3ms preprocess, 166.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 161.6ms
# Speed: 5.2ms preprocess, 161.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 159.4ms
# Speed: 6.3ms preprocess, 159.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 159.9ms
# Speed: 6.2ms preprocess, 159.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 152.3ms
# Speed: 6.0ms preprocess, 152.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 164.5ms
# Speed: 3.1ms preprocess, 164.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 151.1ms
# Speed: 3.5ms preprocess, 151.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 161.7ms
# Speed: 5.2ms preprocess, 161.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 152.4ms
# Speed: 5.1ms preprocess, 152.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 157.1ms
# Speed: 3.1ms preprocess, 157.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 151.3ms
# Speed: 3.3ms preprocess, 151.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 163.0ms
# Speed: 10.6ms preprocess, 163.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 152.6ms
# Speed: 5.5ms preprocess, 152.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 154.8ms
# Speed: 5.3ms preprocess, 154.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 154.3ms
# Speed: 5.0ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 153.8ms
# Speed: 5.5ms preprocess, 153.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 165.9ms
# Speed: 5.1ms preprocess, 165.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 171.5ms
# Speed: 5.3ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 161.1ms
# Speed: 5.0ms preprocess, 161.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 161.0ms
# Speed: 4.9ms preprocess, 161.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 152.2ms
# Speed: 6.2ms preprocess, 152.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 166.5ms
# Speed: 4.7ms preprocess, 166.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 167.8ms
# Speed: 5.2ms preprocess, 167.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 159.7ms
# Speed: 5.1ms preprocess, 159.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 154.4ms
# Speed: 5.3ms preprocess, 154.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 149.2ms
# Speed: 4.8ms preprocess, 149.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 152.3ms
# Speed: 6.0ms preprocess, 152.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 173.3ms
# Speed: 4.9ms preprocess, 173.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 149.5ms
# Speed: 5.0ms preprocess, 149.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 153.2ms
# Speed: 3.5ms preprocess, 153.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 237.8ms
# Speed: 5.1ms preprocess, 237.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 244.9ms
# Speed: 6.1ms preprocess, 244.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 242.1ms
# Speed: 7.5ms preprocess, 242.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 232.9ms
# Speed: 6.5ms preprocess, 232.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 251.1ms
# Speed: 6.1ms preprocess, 251.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 233.2ms
# Speed: 6.6ms preprocess, 233.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 238.8ms
# Speed: 6.3ms preprocess, 238.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 226.2ms
# Speed: 6.2ms preprocess, 226.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 246.5ms
# Speed: 3.2ms preprocess, 246.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 225.5ms
# Speed: 6.7ms preprocess, 225.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 164.2ms
# Speed: 9.4ms preprocess, 164.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 155.5ms
# Speed: 5.6ms preprocess, 155.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 161.6ms
# Speed: 6.2ms preprocess, 161.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 166.0ms
# Speed: 5.2ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 154.7ms
# Speed: 5.1ms preprocess, 154.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 151.4ms
# Speed: 6.1ms preprocess, 151.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.4ms
# Speed: 6.1ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 148.9ms
# Speed: 6.9ms preprocess, 148.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 164.5ms
# Speed: 6.0ms preprocess, 164.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.4ms
# Speed: 5.3ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.6ms
# Speed: 5.2ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.9ms
# Speed: 5.7ms preprocess, 150.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 148.8ms
# Speed: 5.5ms preprocess, 148.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 156.2ms
# Speed: 5.0ms preprocess, 156.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.6ms
# Speed: 5.4ms preprocess, 162.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 146.5ms
# Speed: 5.8ms preprocess, 146.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 151.6ms
# Speed: 4.9ms preprocess, 151.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.6ms
# Speed: 8.6ms preprocess, 150.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 165.4ms
# Speed: 4.8ms preprocess, 165.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 167.4ms
# Speed: 5.6ms preprocess, 167.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.5ms
# Speed: 6.4ms preprocess, 162.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.2ms
# Speed: 5.4ms preprocess, 150.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 155.5ms
# Speed: 3.2ms preprocess, 155.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 164.8ms
# Speed: 3.5ms preprocess, 164.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 160.5ms
# Speed: 3.9ms preprocess, 160.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 171.3ms
# Speed: 3.2ms preprocess, 171.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 153.9ms
# Speed: 5.0ms preprocess, 153.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 150.7ms
# Speed: 7.1ms preprocess, 150.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 148.8ms
# Speed: 5.1ms preprocess, 148.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.6ms
# Speed: 6.3ms preprocess, 150.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.0ms
# Speed: 5.3ms preprocess, 162.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 152.4ms
# Speed: 3.0ms preprocess, 152.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 157.3ms
# Speed: 3.2ms preprocess, 157.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 160.5ms
# Speed: 4.4ms preprocess, 160.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 163.4ms
# Speed: 5.9ms preprocess, 163.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 154.6ms
# Speed: 5.9ms preprocess, 154.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 154.1ms
# Speed: 6.3ms preprocess, 154.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 148.5ms
# Speed: 5.8ms preprocess, 148.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 149.0ms
# Speed: 4.8ms preprocess, 149.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 159.7ms
# Speed: 4.9ms preprocess, 159.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 156.7ms
# Speed: 5.3ms preprocess, 156.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 164.1ms
# Speed: 7.3ms preprocess, 164.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 155.4ms
# Speed: 5.9ms preprocess, 155.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 154.1ms
# Speed: 6.5ms preprocess, 154.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 166.8ms
# Speed: 5.5ms preprocess, 166.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 159.9ms
# Speed: 5.5ms preprocess, 159.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 163.7ms
# Speed: 5.8ms preprocess, 163.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 151.1ms
# Speed: 5.2ms preprocess, 151.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 153.7ms
# Speed: 5.2ms preprocess, 153.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 155.5ms
# Speed: 5.2ms preprocess, 155.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 151.2ms
# Speed: 3.9ms preprocess, 151.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 152.6ms
# Speed: 4.9ms preprocess, 152.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 202.5ms
# Speed: 5.1ms preprocess, 202.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 241.4ms
# Speed: 4.9ms preprocess, 241.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 232.1ms
# Speed: 5.6ms preprocess, 232.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 239.7ms
# Speed: 4.9ms preprocess, 239.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 245.4ms
# Speed: 7.2ms preprocess, 245.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 238.0ms
# Speed: 5.1ms preprocess, 238.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 222.3ms
# Speed: 2.9ms preprocess, 222.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 234.6ms
# Speed: 4.8ms preprocess, 234.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 239.6ms
# Speed: 5.2ms preprocess, 239.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 252.2ms
# Speed: 5.0ms preprocess, 252.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 238.9ms
# Speed: 4.8ms preprocess, 238.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 163.3ms
# Speed: 7.7ms preprocess, 163.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 162.1ms
# Speed: 3.0ms preprocess, 162.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.9ms
# Speed: 5.3ms preprocess, 155.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 145.1ms
# Speed: 5.7ms preprocess, 145.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 154.3ms
# Speed: 5.3ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 150.4ms
# Speed: 5.3ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 167.1ms
# Speed: 4.7ms preprocess, 167.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 158.6ms
# Speed: 4.9ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 161.5ms
# Speed: 5.2ms preprocess, 161.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 155.8ms
# Speed: 6.1ms preprocess, 155.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 155.5ms
# Speed: 4.8ms preprocess, 155.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 171.2ms
# Speed: 5.1ms preprocess, 171.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 152.5ms
# Speed: 4.8ms preprocess, 152.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 161.2ms
# Speed: 4.9ms preprocess, 161.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 155.8ms
# Speed: 4.9ms preprocess, 155.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 159.0ms
# Speed: 3.0ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.6ms
# Speed: 5.7ms preprocess, 157.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 167.4ms
# Speed: 4.9ms preprocess, 167.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 162.9ms
# Speed: 5.1ms preprocess, 162.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.1ms
# Speed: 6.5ms preprocess, 157.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 152.0ms
# Speed: 6.9ms preprocess, 152.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 152.4ms
# Speed: 5.5ms preprocess, 152.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 166.1ms
# Speed: 6.0ms preprocess, 166.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 168.0ms
# Speed: 7.0ms preprocess, 168.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 154.4ms
# Speed: 5.2ms preprocess, 154.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 151.5ms
# Speed: 10.4ms preprocess, 151.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 153.3ms
# Speed: 6.4ms preprocess, 153.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 163.8ms
# Speed: 7.1ms preprocess, 163.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 160.4ms
# Speed: 3.2ms preprocess, 160.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.3ms
# Speed: 3.3ms preprocess, 155.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 153.7ms
# Speed: 5.0ms preprocess, 153.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 148.7ms
# Speed: 5.2ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 153.3ms
# Speed: 5.2ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 163.3ms
# Speed: 3.4ms preprocess, 163.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.5ms
# Speed: 5.4ms preprocess, 157.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 150.1ms
# Speed: 5.0ms preprocess, 150.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 148.3ms
# Speed: 6.7ms preprocess, 148.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 153.9ms
# Speed: 5.7ms preprocess, 153.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 165.9ms
# Speed: 5.3ms preprocess, 165.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 159.6ms
# Speed: 5.2ms preprocess, 159.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 159.7ms
# Speed: 5.3ms preprocess, 159.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.4ms
# Speed: 5.5ms preprocess, 155.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 153.9ms
# Speed: 5.8ms preprocess, 153.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 147.5ms
# Speed: 3.2ms preprocess, 147.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 166.0ms
# Speed: 5.4ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 154.0ms
# Speed: 5.1ms preprocess, 154.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 152.2ms
# Speed: 5.4ms preprocess, 152.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 152.2ms
# Speed: 5.4ms preprocess, 152.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 153.4ms
# Speed: 5.6ms preprocess, 153.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 171.6ms
# Speed: 3.3ms preprocess, 171.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 149.8ms
# Speed: 5.2ms preprocess, 149.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.6ms
# Speed: 8.8ms preprocess, 155.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 210.1ms
# Speed: 4.8ms preprocess, 210.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 239.3ms
# Speed: 5.7ms preprocess, 239.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 243.0ms
# Speed: 5.0ms preprocess, 243.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 226.4ms
# Speed: 6.3ms preprocess, 226.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 240.8ms
# Speed: 5.3ms preprocess, 240.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 249.9ms
# Speed: 4.4ms preprocess, 249.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 227.7ms
# Speed: 5.5ms preprocess, 227.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 235.2ms
# Speed: 5.3ms preprocess, 235.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 233.6ms
# Speed: 5.0ms preprocess, 233.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 252.5ms
# Speed: 8.6ms preprocess, 252.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 234.2ms
# Speed: 6.3ms preprocess, 234.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 180.1ms
# Speed: 6.5ms preprocess, 180.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 159.8ms
# Speed: 6.5ms preprocess, 159.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 157.3ms
# Speed: 6.1ms preprocess, 157.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 162.7ms
# Speed: 6.0ms preprocess, 162.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 155.1ms
# Speed: 5.0ms preprocess, 155.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 154.7ms
# Speed: 5.5ms preprocess, 154.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 152.0ms
# Speed: 3.0ms preprocess, 152.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 150.6ms
# Speed: 5.1ms preprocess, 150.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 161.4ms
# Speed: 5.1ms preprocess, 161.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 147.3ms
# Speed: 5.2ms preprocess, 147.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 159.0ms
# Speed: 5.0ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 160.4ms
# Speed: 5.2ms preprocess, 160.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 152.1ms
# Speed: 5.3ms preprocess, 152.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 152.9ms
# Speed: 5.1ms preprocess, 152.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 160.9ms
# Speed: 6.2ms preprocess, 160.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 148.8ms
# Speed: 5.0ms preprocess, 148.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 152.0ms
# Speed: 4.9ms preprocess, 152.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 159.1ms
# Speed: 4.8ms preprocess, 159.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 162.3ms
# Speed: 6.2ms preprocess, 162.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 169.9ms
# Speed: 6.8ms preprocess, 169.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 153.0ms
# Speed: 4.9ms preprocess, 153.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 157.5ms
# Speed: 9.1ms preprocess, 157.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 170.0ms
# Speed: 5.4ms preprocess, 170.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 166.4ms
# Speed: 3.1ms preprocess, 166.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 158.3ms
# Speed: 5.0ms preprocess, 158.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 151.1ms
# Speed: 5.2ms preprocess, 151.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 157.8ms
# Speed: 5.0ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 159.9ms
# Speed: 3.2ms preprocess, 159.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 150.3ms
# Speed: 3.4ms preprocess, 150.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 163.4ms
# Speed: 3.6ms preprocess, 163.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 146.9ms
# Speed: 5.6ms preprocess, 146.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 151.5ms
# Speed: 6.8ms preprocess, 151.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 148.2ms
# Speed: 4.9ms preprocess, 148.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 149.0ms
# Speed: 7.0ms preprocess, 149.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 170.7ms
# Speed: 5.1ms preprocess, 170.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 148.4ms
# Speed: 5.1ms preprocess, 148.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 151.0ms
# Speed: 7.8ms preprocess, 151.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 149.9ms
# Speed: 5.0ms preprocess, 149.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 155.6ms
# Speed: 5.4ms preprocess, 155.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 147.7ms
# Speed: 3.3ms preprocess, 147.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 177.2ms
# Speed: 5.9ms preprocess, 177.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 157.8ms
# Speed: 6.6ms preprocess, 157.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 156.6ms
# Speed: 5.3ms preprocess, 156.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 166.8ms
# Speed: 5.6ms preprocess, 166.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 153.0ms
# Speed: 6.0ms preprocess, 153.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 174.0ms
# Speed: 5.5ms preprocess, 174.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 158.1ms
# Speed: 5.4ms preprocess, 158.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 149.3ms
# Speed: 5.3ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 157.9ms
# Speed: 4.9ms preprocess, 157.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 150.2ms
# Speed: 5.1ms preprocess, 150.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 168.5ms
# Speed: 4.8ms preprocess, 168.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 218.1ms
# Speed: 3.0ms preprocess, 218.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 241.8ms
# Speed: 6.6ms preprocess, 241.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 232.5ms
# Speed: 5.1ms preprocess, 232.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 255.1ms
# Speed: 5.1ms preprocess, 255.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 241.2ms
# Speed: 5.0ms preprocess, 241.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 242.5ms
# Speed: 5.1ms preprocess, 242.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 242.3ms
# Speed: 5.0ms preprocess, 242.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 241.4ms
# Speed: 5.3ms preprocess, 241.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 trucks, 237.5ms
# Speed: 5.2ms preprocess, 237.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 236.7ms
# Speed: 5.9ms preprocess, 236.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 240.9ms
# Speed: 6.2ms preprocess, 240.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 173.4ms
# Speed: 7.6ms preprocess, 173.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 153.2ms
# Speed: 4.9ms preprocess, 153.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 161.9ms
# Speed: 5.1ms preprocess, 161.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 151.7ms
# Speed: 5.4ms preprocess, 151.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 145.7ms
# Speed: 3.1ms preprocess, 145.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 162.0ms
# Speed: 5.4ms preprocess, 162.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 155.2ms
# Speed: 5.4ms preprocess, 155.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 165.2ms
# Speed: 4.9ms preprocess, 165.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 trucks, 148.7ms
# Speed: 5.7ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 trucks, 154.2ms
# Speed: 5.5ms preprocess, 154.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 148.8ms
# Speed: 3.0ms preprocess, 148.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 161.4ms
# Speed: 3.3ms preprocess, 161.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 164.7ms
# Speed: 5.6ms preprocess, 164.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 148.0ms
# Speed: 5.4ms preprocess, 148.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 146.9ms
# Speed: 3.4ms preprocess, 146.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 147.3ms
# Speed: 5.4ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 166.8ms
# Speed: 5.4ms preprocess, 166.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 163.9ms
# Speed: 5.2ms preprocess, 163.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 147.3ms
# Speed: 5.3ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 152.1ms
# Speed: 5.4ms preprocess, 152.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 149.5ms
# Speed: 5.1ms preprocess, 149.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 167.8ms
# Speed: 5.4ms preprocess, 167.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 159.7ms
# Speed: 5.2ms preprocess, 159.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 158.7ms
# Speed: 5.8ms preprocess, 158.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 153.5ms
# Speed: 5.3ms preprocess, 153.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 149.4ms
# Speed: 5.7ms preprocess, 149.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 149.8ms
# Speed: 5.3ms preprocess, 149.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 169.0ms
# Speed: 5.8ms preprocess, 169.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 154.9ms
# Speed: 5.5ms preprocess, 154.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 151.4ms
# Speed: 5.0ms preprocess, 151.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 150.5ms
# Speed: 5.8ms preprocess, 150.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 156.4ms
# Speed: 5.1ms preprocess, 156.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 167.3ms
# Speed: 5.2ms preprocess, 167.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 160.6ms
# Speed: 8.7ms preprocess, 160.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 154.0ms
# Speed: 5.1ms preprocess, 154.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 153.3ms
# Speed: 7.3ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 150.0ms
# Speed: 5.1ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 165.6ms
# Speed: 5.6ms preprocess, 165.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 162.0ms
# Speed: 5.7ms preprocess, 162.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 155.4ms
# Speed: 6.4ms preprocess, 155.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 153.1ms
# Speed: 6.0ms preprocess, 153.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 159.0ms
# Speed: 5.1ms preprocess, 159.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 155.7ms
# Speed: 5.2ms preprocess, 155.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 171.9ms
# Speed: 4.7ms preprocess, 171.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 151.6ms
# Speed: 8.7ms preprocess, 151.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 156.4ms
# Speed: 6.2ms preprocess, 156.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 155.9ms
# Speed: 5.4ms preprocess, 155.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 153.4ms
# Speed: 3.0ms preprocess, 153.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 178.3ms
# Speed: 8.7ms preprocess, 178.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 157.1ms
# Speed: 6.9ms preprocess, 157.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 151.9ms
# Speed: 7.0ms preprocess, 151.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 152.5ms
# Speed: 3.0ms preprocess, 152.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 249.2ms
# Speed: 5.2ms preprocess, 249.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 249.9ms
# Speed: 7.8ms preprocess, 249.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 235.1ms
# Speed: 5.2ms preprocess, 235.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 228.8ms
# Speed: 5.0ms preprocess, 228.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 245.3ms
# Speed: 5.0ms preprocess, 245.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 244.4ms
# Speed: 5.1ms preprocess, 244.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 228.5ms
# Speed: 5.8ms preprocess, 228.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 232.0ms
# Speed: 5.5ms preprocess, 232.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 250.3ms
# Speed: 7.1ms preprocess, 250.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 228.7ms
# Speed: 3.1ms preprocess, 228.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 190.6ms
# Speed: 5.5ms preprocess, 190.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 154.7ms
# Speed: 5.0ms preprocess, 154.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 159.0ms
# Speed: 3.2ms preprocess, 159.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 168.5ms
# Speed: 5.7ms preprocess, 168.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 160.5ms
# Speed: 5.8ms preprocess, 160.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 152.8ms
# Speed: 5.4ms preprocess, 152.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 163.0ms
# Speed: 5.3ms preprocess, 163.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 168.2ms
# Speed: 5.3ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 168.8ms
# Speed: 3.2ms preprocess, 168.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 154.3ms
# Speed: 9.7ms preprocess, 154.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 154.5ms
# Speed: 3.0ms preprocess, 154.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 153.2ms
# Speed: 5.2ms preprocess, 153.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 163.9ms
# Speed: 6.0ms preprocess, 163.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 174.9ms
# Speed: 5.2ms preprocess, 174.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 159.2ms
# Speed: 5.2ms preprocess, 159.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 158.4ms
# Speed: 3.0ms preprocess, 158.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 157.1ms
# Speed: 5.3ms preprocess, 157.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 168.3ms
# Speed: 6.3ms preprocess, 168.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 165.5ms
# Speed: 5.1ms preprocess, 165.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 159.9ms
# Speed: 5.0ms preprocess, 159.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 157.1ms
# Speed: 5.0ms preprocess, 157.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 162.8ms
# Speed: 5.8ms preprocess, 162.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 170.7ms
# Speed: 5.4ms preprocess, 170.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 153.6ms
# Speed: 6.7ms preprocess, 153.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 158.4ms
# Speed: 5.1ms preprocess, 158.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 154.6ms
# Speed: 5.1ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 153.5ms
# Speed: 5.1ms preprocess, 153.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 163.1ms
# Speed: 3.1ms preprocess, 163.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 152.0ms
# Speed: 4.0ms preprocess, 152.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 164.6ms
# Speed: 5.3ms preprocess, 164.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 142.5ms
# Speed: 5.2ms preprocess, 142.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 149.3ms
# Speed: 5.0ms preprocess, 149.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 164.7ms
# Speed: 6.2ms preprocess, 164.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 156.8ms
# Speed: 5.1ms preprocess, 156.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 170.9ms
# Speed: 6.2ms preprocess, 170.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 156.1ms
# Speed: 5.0ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 156.1ms
# Speed: 5.9ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 163.3ms
# Speed: 5.1ms preprocess, 163.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 154.3ms
# Speed: 6.4ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 154.3ms
# Speed: 5.8ms preprocess, 154.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 157.9ms
# Speed: 6.2ms preprocess, 157.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 151.6ms
# Speed: 5.1ms preprocess, 151.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 161.3ms
# ...
# Speed: 4.9ms preprocess, 260.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 241.3ms
# Speed: 5.8ms preprocess, 241.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 220.6ms
# Speed: 8.5ms preprocess, 220.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 169.5ms
# Speed: 5.2ms preprocess, 169.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 155.1ms
# Speed: 6.6ms preprocess, 155.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 157.5ms
# Speed: 5.6ms preprocess, 157.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 147.2ms
# Speed: 7.1ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 154.9ms
# Speed: 3.1ms preprocess, 154.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 161.5ms
# Speed: 5.2ms preprocess, 161.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 166.6ms
# Speed: 5.1ms preprocess, 166.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 161.9ms
# Speed: 4.9ms preprocess, 161.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 151.1ms
# Speed: 5.0ms preprocess, 151.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 153.9ms
# Speed: 5.8ms preprocess, 153.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 153.9ms
# Speed: 5.6ms preprocess, 153.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 171.5ms
# Speed: 5.7ms preprocess, 171.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 152.8ms
# Speed: 5.1ms preprocess, 152.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 153.7ms
# Speed: 5.3ms preprocess, 153.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 151.9ms
# Speed: 5.2ms preprocess, 151.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 174.3ms
# Speed: 5.2ms preprocess, 174.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 158.4ms
# Speed: 6.7ms preprocess, 158.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 159.3ms
# Speed: 6.6ms preprocess, 159.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 158.1ms
# Speed: 5.2ms preprocess, 158.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 151.5ms
# Speed: 6.1ms preprocess, 151.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 165.0ms
# Speed: 5.6ms preprocess, 165.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 162.3ms
# Speed: 9.0ms preprocess, 162.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 156.6ms
# Speed: 5.1ms preprocess, 156.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 161.9ms
# Speed: 7.7ms preprocess, 161.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 158.6ms
# Speed: 5.5ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 166.4ms
# Speed: 5.5ms preprocess, 166.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 166.3ms
# Speed: 5.1ms preprocess, 166.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 157.4ms
# Speed: 4.9ms preprocess, 157.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 162.8ms
# Speed: 5.2ms preprocess, 162.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 161.2ms
# Speed: 5.3ms preprocess, 161.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 169.1ms
# Speed: 5.6ms preprocess, 169.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 166.8ms
# Speed: 5.4ms preprocess, 166.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 155.7ms
# Speed: 6.7ms preprocess, 155.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 163.6ms
# Speed: 5.1ms preprocess, 163.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 155.6ms
# Speed: 5.7ms preprocess, 155.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 162.1ms
# Speed: 3.2ms preprocess, 162.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 160.3ms
# Speed: 3.9ms preprocess, 160.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 160.5ms
# Speed: 5.9ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.4ms
# Speed: 5.2ms preprocess, 157.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 152.3ms
# Speed: 5.8ms preprocess, 152.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 166.0ms
# Speed: 5.7ms preprocess, 166.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 164.7ms
# Speed: 8.1ms preprocess, 164.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 163.4ms
# Speed: 5.3ms preprocess, 163.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 164.0ms
# Speed: 4.0ms preprocess, 164.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 156.4ms
# Speed: 5.7ms preprocess, 156.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 165.5ms
# Speed: 6.2ms preprocess, 165.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 152.7ms
# Speed: 6.0ms preprocess, 152.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 170.5ms
# Speed: 5.1ms preprocess, 170.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.6ms
# Speed: 4.9ms preprocess, 157.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 200.3ms
# Speed: 6.0ms preprocess, 200.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 243.5ms
# Speed: 3.2ms preprocess, 243.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 244.0ms
# Speed: 5.3ms preprocess, 244.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 235.1ms
# Speed: 3.1ms preprocess, 235.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 224.2ms
# Speed: 3.1ms preprocess, 224.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 230.7ms
# Speed: 6.1ms preprocess, 230.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 255.3ms
# Speed: 6.2ms preprocess, 255.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 242.3ms
# Speed: 4.9ms preprocess, 242.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 239.9ms
# Speed: 5.3ms preprocess, 239.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 239.1ms
# Speed: 6.3ms preprocess, 239.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 236.5ms
# Speed: 3.2ms preprocess, 236.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 208.0ms
# Speed: 6.5ms preprocess, 208.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 151.1ms
# Speed: 6.1ms preprocess, 151.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 153.8ms
# Speed: 5.2ms preprocess, 153.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 152.6ms
# Speed: 5.1ms preprocess, 152.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 158.3ms
# Speed: 3.3ms preprocess, 158.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 160.0ms
# Speed: 5.3ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 165.5ms
# Speed: 6.0ms preprocess, 165.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 159.6ms
# Speed: 4.9ms preprocess, 159.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 154.9ms
# Speed: 5.6ms preprocess, 154.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 169.9ms
# Speed: 6.0ms preprocess, 169.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 161.1ms
# Speed: 5.5ms preprocess, 161.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 165.8ms
# Speed: 5.4ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 162.2ms
# Speed: 5.2ms preprocess, 162.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 164.6ms
# Speed: 5.5ms preprocess, 164.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 170.6ms
# Speed: 5.8ms preprocess, 170.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 167.2ms
# Speed: 5.1ms preprocess, 167.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 158.7ms
# Speed: 9.6ms preprocess, 158.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 160.5ms
# Speed: 5.6ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 156.8ms
# Speed: 5.4ms preprocess, 156.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 165.6ms
# Speed: 6.9ms preprocess, 165.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 156.2ms
# Speed: 5.2ms preprocess, 156.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 163.7ms
# Speed: 5.1ms preprocess, 163.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 163.0ms
# Speed: 4.0ms preprocess, 163.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 159.2ms
# Speed: 5.1ms preprocess, 159.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 155.1ms
# Speed: 5.8ms preprocess, 155.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 160.0ms
# Speed: 3.4ms preprocess, 160.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 163.2ms
# Speed: 3.2ms preprocess, 163.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 153.3ms
# Speed: 3.1ms preprocess, 153.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.0ms
# Speed: 5.0ms preprocess, 155.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 154.6ms
# Speed: 5.4ms preprocess, 154.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 171.0ms
# Speed: 5.3ms preprocess, 171.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 162.2ms
# Speed: 5.5ms preprocess, 162.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 156.1ms
# Speed: 5.8ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 160.8ms
# Speed: 5.1ms preprocess, 160.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 154.6ms
# Speed: 5.1ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 171.5ms
# Speed: 6.7ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 171.5ms
# Speed: 5.0ms preprocess, 171.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 178.1ms
# Speed: 5.6ms preprocess, 178.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 159.4ms
# Speed: 5.1ms preprocess, 159.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 148.7ms
# Speed: 5.1ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 157.9ms
# Speed: 7.2ms preprocess, 157.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 170.9ms
# Speed: 5.5ms preprocess, 170.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 160.8ms
# Speed: 5.5ms preprocess, 160.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 160.2ms
# Speed: 5.2ms preprocess, 160.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 158.9ms
# Speed: 5.1ms preprocess, 158.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 156.1ms
# Speed: 4.9ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 168.2ms
# Speed: 6.8ms preprocess, 168.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 151.0ms
# Speed: 5.2ms preprocess, 151.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 156.9ms
# Speed: 6.5ms preprocess, 156.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 148.8ms
# Speed: 5.2ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 156.1ms
# Speed: 6.4ms preprocess, 156.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 215.3ms
# Speed: 3.4ms preprocess, 215.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 251.7ms
# Speed: 7.1ms preprocess, 251.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Video saved to: /content/output_video.mp4

# %%
import cv2

# Open a video file
video_path = '/content/output_video.mp4'
cap = cv2.VideoCapture(video_path)

# Initialize the tracker
tracker = cv2.TrackerKCF_create()

# Read the first frame
ret, frame = cap.read()
if not ret:
    print("Error: Could not read video.")

# Select a bounding box to track
bbox = cv2.selectROI('Tracking', frame, False)
tracker.init(frame, bbox)

# Track the object in subsequent frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Update the tracker
    success, bbox = tracker.update(frame)

    # Draw the bounding box
    if success:
        x, y, w, h = [int(v) for v in bbox]
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    else:
        cv2.putText(frame, "Tracking failed", (100, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('Object Tracking', frame)

    # Exit if 'q' is pressed
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# Release the video capture object and close windows
cap.release()
cv2.destroyAllWindows()
